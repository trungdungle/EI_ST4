# %% [markdown]
# # Classification utilisant KNN et SVC

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dans le fichier Iris.csv, la colonne "Species" 0= setosa, 1=versicolor et 2=virginica

# %% [markdown]
# 0. Importer les librairies nécessaires (pandas, numpy, matplotlib, etc.)

# %% [markdown]
# 1. Importer les données du fichier iris.csv dans un dataframe

# %% [markdown]
# 2. Afficher les informations et les statistiques du dataframe

# %% [markdown]
# Vos commentaires sur la partition des types d'iris dans la base de données
#
# Votre réponse:

# %% [markdown]
# 3. Afficher graphiquement la database
#
# Chaque individu sera représenté avec des petits cercles (marker) de coucleurs différentes (petal_length, petal_width) selon la "species"  g= setosa, r= versicolor et b=virbinica

# %%
petal_length = df["petal_length"]
petal_width = df["petal_width"]
lab = df["species"]

# %%
plt.axis('equal')
plt.scatter(petal_length[lab == 0], petal_width[lab == 0], color='g', label='setosa')
plt.scatter(petal_length[lab == 1], petal_width[lab == 1], color='r', label='versicolor')
plt.scatter(petal_length[lab == 2], petal_width[lab == 2], color='b', label='virginica')
plt.legend()
plt.show()

# %% [markdown]
# 4. Placer un pétale avec 2 cm de large et 4,5 cm de long avec la couleur noire (nommé point T)

# %% [markdown]
# 5. Séparation: Entrainement, test

# %% [markdown]
# 6. KNN: faire la prédiction pour les 2 ensembles d'entrainement et de test, afficher l'accuracy, et la matrice de confusion avec k = 3
#
# Prédire la  classe du point T de la question 4
#
# Explication sur KNN: https://www.ibm.com/fr-fr/topics/knn
#
# Illustration:
#
# ![image.png](attachment:image.png)
#
#
#
# KNN pour la classification dans Scikit-learn: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn-neighbors-kneighborsclassifier
#
#
# Accuracy score: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html
#
# Confusion matrix: https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html#confusion-matrix

# %% [markdown]
# 7. Refaire la question 6 avec une valeur significativement différente de k
#
# Donner votre remarque l'impact de k sur les performnances de KNN

# %% [markdown]
# 8. Construire un modèle de classification utilisant SVC. Evaluler les performances en comparant avec le modèle KNN
#
# Explications sur SVM:
#
# https://www.ibm.com/fr-fr/topics/support-vector-machine?mhsrc=ibmsearch_a&mhq=svm
#
#
# SVM pour la classification dans Scikit-learn: https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC
#
# Illustration:
#
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# votre remarque:
