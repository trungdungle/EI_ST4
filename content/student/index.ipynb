# %% [markdown]
# # EI ST4
#
# Liens vers les études:
# - [Etude1_RLsimple.ipynb](etude1_RLsimple/Etude1_RLsimple.ipynb)
# - [Etude2_Regression_lineaire_multiple.ipynb](etude2_RLmultiple/Etude2_Regression_lineaire_multiple.ipynb)
# - [Etude3_Modele_Regression_polynomiale.ipynb](etude3_Reg_polynomiale/Etude3_Modele_Regression_polynomiale.ipynb)
# - [etude4_KNN_SVM.ipynb](etude4_KNN_SVC/etude4_KNN_SVM.ipynb)
# - [Etude5_cross-validation.ipynb](etude5_cross_validation/Etude5_cross-validation.ipynb)
# - [Etude6_hyperparametres.ipynb](etude6_hyperparametres/Etude6_hyperparametres.ipynb)
