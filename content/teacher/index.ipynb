# %% [markdown]
# # EI ST4
#
# Liens vers les études:
# - [correction_etude1_RLsimple.ipynb](etude1_RLsimple/correction_etude1_RLsimple.ipynb)
# - [correction_etude2_RLmultiple.ipynb](etude2_RLmultiple/correction_etude2_RLmultiple.ipynb)
# - [Correction_Regression_polynomiale.ipynb](etude3_Reg_polynomiale/correction_etude1_RLsimple.ipynb)
# - [Correction_KNN_SVM_Iris.ipynb](etude4_KNN_SVC/Correction_KNN_SVM_Iris.ipynb)
# - [correction_arbre_cv.ipynb](etude5_cross_validation/correction_arbre_cv.ipynb)
# - [correction_svm_hyperparametres.ipynb](etude6_hyperparametres/correction_svm_hyperparametres.ipynb)
